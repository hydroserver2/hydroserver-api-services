# %%
from sqlalchemy import create_engine
from sensorthings.schema import Base

# %%
engine = create_engine('sqlite:///st_test.db', echo=True)

# %%
Base.metadata.create_all(engine)
# Out:
# 2022-12-28 18:04:25,187 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-12-28 18:04:25,187 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("thing_location")
# 2022-12-28 18:04:25,188 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-12-28 18:04:25,188 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("thing_location")
# 2022-12-28 18:04:25,189 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-12-28 18:04:25,189 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("thing")
# 2022-12-28 18:04:25,189 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-12-28 18:04:25,190 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("thing")
# 2022-12-28 18:04:25,190 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-12-28 18:04:25,191 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("location_encoding_type")
# 2022-12-28 18:04:25,191 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-12-28 18:04:25,191 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("location_encoding_type")
# ...
